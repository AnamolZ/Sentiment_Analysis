# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import re
import emoji
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer

nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    text = emoji.demojize(text, delimiters=(" ", " "))
    text = re.sub(r'@\w+', 'socialmention', text)
    text = re.sub(r'#\w+', 'hashtag', text)
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    words = word_tokenize(text.lower())
    words = [word for word in words if word.isalpha()]
    return ' '.join(words)

stop_words = set(stopwords.words('english'))

options = webdriver.ChromeOptions()
options.add_argument('headless')
driver = webdriver.Chrome(options=options)

url = "https://www.amazon.com/Perfect-Son-gripping-psychological-breathtaking/dp/B086PMZR78/"
driver.get(url)
time.sleep(5)
html = driver.page_source
driver.quit()
soup = BeautifulSoup(html, 'html.parser')
reviews = soup.find_all('span', {'data-hook': 'review-body'})
review_texts = [review.get_text(strip=True) for review in reviews]

vectorizer = TfidfVectorizer()
classifier = LinearSVC()
preprocess = FunctionTransformer(lambda x: [preprocess_text(text) for text in x], validate=False)

training_data = pd.read_csv('Sentimental Analysis Data.csv')
training_data['text'] = training_data['text'].fillna('')

model_pipeline = make_pipeline(preprocess, vectorizer, classifier)
model_pipeline.fit(training_data['text'], training_data['sentiment'])

sentiments = []
ratings = []
for review in review_texts:
    predicted_label = model_pipeline.predict([review])[0]
    sentiments.append(predicted_label)
    rating = 5 if predicted_label == 'positive' else 1
    ratings.append(rating)
    print(f"Review: {review}\nPredicted Sentiment: {predicted_label}, Rating: {rating}")

average_rating = sum(ratings) / len(ratings) if ratings else 0
print(f"Overall product rating based on user reviews: {average_rating:.2f}/5")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anmol\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anmol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Review: This truly was a book I didn’t want to put down and thought I had it all figured out but I was so wrong. It really had a twist towards the end. The main character Erika Cass had a pretty good life except her son was different from others. She’s known this all along and has tried to keep him and others safe from him. When a girl her son likes goes missing, she right away assumes he’s the one who did it. It also appears the police and community feel this same. The book is written in each chapter either by a character or an interview about the event of the missing girl. I’m not saying anymore because it really has a great twist. A super good read.Read more
# Predicted Sentiment: positive, Rating: 5
# Review: Good read, has a great twist. I didn’t see coming. This was a proverbial hard to put down. good characters good developments, hard to guess what was happening?Read more
# Predicted Sentiment: positive, Rating: 5
# Review: I have read numerous novels by this author lately because she knows how to draw you into the story and just when you think it is going one way, there is always various twists and turns so that when you think you have figured out the theme, you find out you were wrong.Since I have a background in law enforcement, and I have handled many cases involving psychopathic criminals, and I found this book to be a fascinating read.  I was also able to figure out who was the guilty party; nevertheless, I never give away too much information when reviewing any novel.  If you enjoy reading the psychological theme novels by Freida McFadden, you should checkout this one. I found it to be a real page turner.Rating: 5 Stars.  Joseph J. Truncale (Author: The Mighty Pen: Your self-defense friend: tactical use of the pen for self-defense).Read more
# Predicted Sentiment: neutral, Rating: 1
# Review: Read this in a an afternoon. Very fast moving and a very surprising twist. Couldn’t put it down. Classic Freida McFadden. You won’t be sorry if you read this. Good entertainment for a lazy afternoon.Read more
# Predicted Sentiment: positive, Rating: 5
# Review: The Perfect Sonby Freida McFadden4/5 ⭐️Life is perfect for Erika Cass- a beautiful family, home, and low-stress job. Until she gets a knock on the door from two detectives. A high-school girl is missing and the last person to see this girl alive was Erika’s son, Liam.Erika loves Liam unconditionally but has known since kindergarten that he has a dark side. Now in high school, Liam seems like the perfect son- well-mannered, smart, and involved at school. Erika wants to believe he is innocent but her heart is filled with doubt. On top of Liam’s troubles, Erika’s mother confesses that she has been lying to Erika for years. The father who Erika thought was dead is actually in jail for murder. Could this be the root of Liam’s dark side? Can Erika sift through all the lies and figure out the truth before it is too late for this missing girl?The Perfect Son was another great thriller by McFadden. I enjoyed the mix of storytelling and the transcribed police interviews. Freida's writing is always amazing! She has a way of tricking me into thinking both the best and the worst about all the characters. Erica, the main character, is very relatable but her unconditional love for her children, especially her son plants seeds of doubt in your head. Unfortunately, I was able to figure out the main twist halfway through the book. Although the epilogue was surprisingly entertaining even after everything was revealed. If you are looking for an entertaining, fast-paced thriller this is the book for you.Read more
# Predicted Sentiment: positive, Rating: 5
# Review: Just can’t get enough of Freida’s work. She is talented and knows how to keep a reader on the edge of their seat. This book was entertaining and had many twist/turns. This book and the housewife series are gold. Give it a try!Read more
# Predicted Sentiment: positive, Rating: 5
# Review: This book had me captivated from start to finish. The storytelling kept me at the edge of my seat. As I was reading I could see it being played out like a movie. 10/10 👍🏾Read more
# Predicted Sentiment:  positive, Rating: 1
# Review: I cant get enough of her books - her awesome imagination - her incredible writing -leading us & twisting our minds to think we know exactly where she wants to take us - to the very edge of a cliff - and at the last minute turns us to another path hidden beneath our feet - and we have to follow - our hearts beating fast as we anticipate where our fear will take us next with her words.....OMG - I cant stop - I just have to read one more chapter.....I just have to buy one more book - her incredible writing -books stacked one on top of another - all by Freida - in my ipad charging on my night stand - anticipating my next mind ride.....  Linda Heuser, 4/25/'24Read more
# Predicted Sentiment: negative, Rating: 1
# Review: It is a good book to read. And very easy language. One must read it. Great one to read for free.Read more
# Predicted Sentiment: positive, Rating: 5
# Review: It was a page turner for sure! Easy read with a twist at the end that I wasn't expecting.Read more
# Predicted Sentiment: positive, Rating: 5
# Review: Could not put this book down great from start to finish lots of twists and turns highly recommended. Moving onto next book nowRead more
# Predicted Sentiment: positive, Rating: 5
# Review: Ein typischer Freida McFadden Thriller ❤️😍 Es macht einfach Spaß, ihre Bücher zu lesen. Sie sind spannend bis zur letzten Sekunde!Read more
# Predicted Sentiment:  positive, Rating: 1
# Review: Oh my God!!! Unbelievable ending. I didn't even think it would take such a u-turn. Best psychological thriller I've read so far. Amazing plot and story line.Read more
# Predicted Sentiment: positive, Rating: 5
# Overall product rating based on user reviews: 3.77/5
